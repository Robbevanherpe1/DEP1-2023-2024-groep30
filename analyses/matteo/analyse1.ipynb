# %% [markdown]
# # Analyse 1
#
# We kunnen ook inzetten op 'Beide teams scoren': Ja of Nee.
#
# We willen daar niet zomaar blindelings op inzetten maar een 'gefundeerde' keuze maken.
#
# Als de roepnamen van 2 clubs worden gegeven, bereken dan hoe vaak de beide teams scoorden in de vroegere duels: Ja of Nee. (inclusief de percentages)

# %%
# Importing the necessary packages
import numpy as np                                  # "Scientific computing"
import scipy.stats as stats                         # Statistical tests

import pandas as pd                                 # Data Frame
from pandas.api.types import CategoricalDtype

import matplotlib.pyplot as plt                     # Basic visualisation
from statsmodels.graphics.mosaicplot import mosaic  # Mosaic diagram
import seaborn as sns                               # Advanced data visualisation

# %%
# Dataset inladen
jpldata = pd.read_csv("D:/Hogent/Visual Studio Code/DEP/DEP1-2023-2024-groep30/transfermarkt/data/correcte_data/wedstrijden.csv", sep=";")

# %%
# De eerste 10 rijen van de dataset bekijken
jpldata.head(10)
# Out:
#         Datum Tijdstip       Id  StamnummerThuisploeg    RoepnaamThuisploeg  \
# 0  1960-09-04    15:00  4008203                   373     Sint-Truidense VV
# 1  1960-09-04    15:00  4008204                    90       Eendracht Aalst
# 2  1960-09-04    15:00  4008205                   246     Olympic Charleroi
# 3  1960-09-04    15:00  4008206                    13             Beerschot
# 4  1960-09-04    15:00  4008207                     3           Club Brugge
# 5  1960-09-04    15:00  4008208                     2   Daring Club Brussel
# 6  1960-09-04    15:00  4008209                     4              RFC Luik
# 7  1960-09-04    15:00  4008210                   553    Waterschei SV Thor
# 8  1960-09-11    15:00  4008218                    33            Verviétois
# 9  1960-09-11    15:00  4008217                    10  Union Saint-Gilloise
#
#    StamnummerUitploeg      RoepnaamUitploeg  FinaleStandThuisploeg  \
# 0                  16         Standard Luik                      0
# 1                   1      Royal Antwerp FC                      3
# 2                  35        RSC Anderlecht                      0
# 3                  33            Verviétois                      1
# 4                  10  Union Saint-Gilloise                      1
# 5                3434          Patro Eisden                      2
# 6                   7              KAA Gent                      2
# 7                  30             Lierse SK                      5
# 8                 553    Waterschei SV Thor                      1
# 9                 373     Sint-Truidense VV                      3
#
#    FinaleStandUitploeg Seizoen  Speeldag
# 0                    2   60/61         1
# 1                    2   60/61         1
# 2                    7   60/61         1
# 3                    0   60/61         1
# 4                    2   60/61         1
# 5                    1   60/61         1
# 6                    1   60/61         1
# 7                    0   60/61         1
# 8                    3   60/61         2
# 9                    0   60/61         2

# %%
# Analyse
