# %% [markdown]
# # Analyse Gevorderd 5
#
# Hoeveel procent van de ploegen die na een derde van het seizoen (neem op speeldag 10) in de top 6 van het klassement stonden, staan op de laatste speeldag van het seizoen nog in de top 6 van het klassement?

# %%
import pandas as pd

# Load de dataset
df = pd.read_csv(r"C:\Users\Robbe\Documents\School_jaar_2\sem2\DEP\klassement.csv", delimiter=';')

df.head(10),df.columns
# Out:
# (   Seizoen  Speeldag  Stand  Stamnummer                 Ploeg  AantalGespeeld  \
#  0     1960         1      1          35        RSC Anderlecht               1
#  1     1960         1      2         553    Waterschei SV Thor               1
#  2     1960         1      3          16         Standard Luik               1
#  3     1960         1      4          90       Eendracht Aalst               1
#  4     1960         1      5           2   Daring Club Brussel               1
#  5     1960         1      5           4              RFC Luik               1
#  6     1960         1      5          10  Union Saint-Gilloise               1
#  7     1960         1      8          13             Beerschot               1
#  8     1960         1      9           1      Royal Antwerp FC               1
#  9     1960         1     10           3           Club Brugge               1
#
#     AantalGewonnen  AantalGelijk  AantalVerloren  DoelpuntenVoor  \
# ...

# %%
# Zorg ervoor dat de data gesorteerd is op 'Seizoen', 'Speeldag' en 'Stand'
df_sorted = df.sort_values(by=['Seizoen', 'Speeldag', 'Stand'])

# Unieke seizoenen in de dataset
seasons = df_sorted['Seizoen'].unique()

percentages = []

seasons
# Out:
# array([1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970,
#        1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981,
#        1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992,
#        1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#        2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#        2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023], dtype=int64)

# %%
for season in seasons:
    # Filter data voor het huidige seizoen
    season_data = df_sorted[df_sorted['Seizoen'] == season]

    # Filter om de teams in de top 6 op speeldag 10 te vinden
    top6_day10 = season_data[season_data['Speeldag'] == 10].head(6)['Ploeg'].tolist()

    # Bepaal de laatste speeldag voor het huidige seizoen
    last_matchday = season_data['Speeldag'].max()

    # Filter om de teams in de top 6 op de laatste speeldag van het huidige seizoen te vinden
    top6_last_day = season_data[season_data['Speeldag'] == last_matchday].head(6)['Ploeg'].tolist()

    # Kijk naar verschil
    still_top6 = [team for team in top6_day10 if team in top6_last_day]

    # Bereken het percentage voor het huidige seizoen
    if top6_day10:
        percentage = (len(still_top6) / len(top6_day10)) * 100
        percentages.append(percentage)

percentages
# Out:
# [83.33333333333334,
#  66.66666666666666,
#  66.66666666666666,
#  100.0,
#  100.0,
#  66.66666666666666,
#  83.33333333333334,
#  50.0,
#  83.33333333333334,
#  83.33333333333334,
#  50.0,
#  83.33333333333334,
#  50.0,
#  50.0,
#  66.66666666666666,
#  66.66666666666666,
#  66.66666666666666,
#  66.66666666666666,
#  33.33333333333333,
#  66.66666666666666,
#  66.66666666666666,
#  66.66666666666666,
#  83.33333333333334,
#  83.33333333333334,
#  100.0,
#  83.33333333333334,
#  66.66666666666666,
#  100.0,
#  83.33333333333334,
#  66.66666666666666,
#  83.33333333333334,
#  83.33333333333334,
#  66.66666666666666,
#  66.66666666666666,
#  66.66666666666666,
#  83.33333333333334,
#  83.33333333333334,
#  83.33333333333334,
#  66.66666666666666,
#  33.33333333333333,
#  50.0,
#  83.33333333333334,
#  100.0,
#  100.0,
#  66.66666666666666,
#  66.66666666666666,
#  83.33333333333334,
#  66.66666666666666,
#  83.33333333333334,
#  50.0,
#  83.33333333333334,
#  66.66666666666666,
# ...

# %%
# Bereken het gemiddelde percentage over alle seizoenen
gemiddeld_percentage = sum(percentages) / len(percentages) if percentages else 0

print(f"Gemiddeld percentage van teams die in de top 6 blijven: {gemiddeld_percentage:.2f}%")
# Out:
# Gemiddeld percentage van teams die in de top 6 blijven: 73.18%
